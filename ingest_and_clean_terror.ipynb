# %%
from pyspark.sql.functions import col

df_raw = spark.table("bigdata_finals.default.raw_terorism")
df_raw.show(5)
df_raw.printSchema()
# Out:
# +------------+-----+------+----+----------+--------+----------+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------+--------+-------+-----+-----+-----+---------+-----------+---------------+--------+-------+-------+-----------+--------------------+-----------+---------------+-----------+---------------+---------+--------------------+------------+--------------------+--------------------+--------------------+-------+------------------+---------+-------------+------------+----------------+-----+-------+-------+-----------+---------+-------------+------------+----------------+-----+-------+-------+-----------+--------------------+--------+------+---------+------+---------+------+-----------+-----------+-----------+----------+------+--------+-------+---------+-------------+------+----------+--------------+------+----------+--------------+---------+---------+-------------+------------+--------------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+----------+-----+-------+--------+------+--------+--------+--------+----------+--------------+---------+-----------+---------+--------+----------+------+-----+------+-------------+------+---------+-----------+----------+------------+----------+--------------+------------------+---------+--------+------+------+------+--------+-------+--------+--------+-------+-------+
# |     eventid|iyear|imonth|iday|approxdate|extended|resolution|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|specificity|vicinity|location|summary|crit1|crit2|crit3|doubtterr|alternative|alternative_txt|multiple|success|suicide|attacktype1|     attacktype1_txt|attacktype2|attacktype2_txt|attacktype3|attacktype3_txt|targtype1|       targtype1_txt|targsubtype1|    targsubtype1_txt|               corp1|             target1|natlty1|       natlty1_txt|targtype2|targtype2_txt|targsubtype2|targsubtype2_txt|corp2|target2|natlty2|natlty2_txt|targtype3|targtype3_txt|targsubtype3|targsubtype3_txt|corp3|target3|natlty3|natlty3_txt|               gname|gsubname|gname2|gsubname2|gname3|gsubname3|motive|guncertain1|guncertain2|guncertain3|individual|nperps|nperpcap|claimed|claimmode|claimmode_txt|claim2|claimmode2|claimmode2_txt|claim3|claimmode3|claimmode3_txt|compclaim|weaptype1|weaptype1_txt|weapsubtype1|    weapsubtype1_txt|weaptype2|weaptype2_txt|weapsubtype2|weapsubtype2_txt|weaptype3|weaptype3_txt|weapsubtype3|weapsubtype3_txt|weaptype4|weaptype4_txt|weapsubtype4|weapsubtype4_txt|weapdetail|nkill|nkillus|nkillter|nwound|nwoundus|nwoundte|property|propextent|propextent_txt|propvalue|propcomment|ishostkid|nhostkid|nhostkidus|nhours|ndays|divert|kidhijcountry|ransom|ransomamt|ransomamtus|ransompaid|ransompaidus|ransomnote|hostkidoutcome|hostkidoutcome_txt|nreleased|addnotes|scite1|scite2|scite3|dbsource|INT_LOG|INT_IDEO|INT_MISC|INT_ANY|related|
# +------------+-----+------+----+----------+--------+----------+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------+--------+-------+-----+-----+-----+---------+-----------+---------------+--------+-------+-------+-----------+--------------------+-----------+---------------+-----------+---------------+---------+--------------------+------------+--------------------+--------------------+--------------------+-------+------------------+---------+-------------+------------+----------------+-----+-------+-------+-----------+---------+-------------+------------+----------------+-----+-------+-------+-----------+--------------------+--------+------+---------+------+---------+------+-----------+-----------+-----------+----------+------+--------+-------+---------+-------------+------+----------+--------------+------+----------+--------------+---------+---------+-------------+------------+--------------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+----------+-----+-------+--------+------+--------+--------+--------+----------+--------------+---------+-----------+---------+--------+----------+------+-----+------+-------------+------+---------+-----------+----------+------------+----------+--------------+------------------+---------+--------+------+------+------+--------+-------+--------+--------+-------+-------+
# |197000000001| 1970|     7|   2|      NULL|       0|      NULL|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          1|       Assassination|       NULL|           NULL|       NULL|           NULL|       14|Private Citizens ...|          68|      Named Civilian|                NULL|        Julio Guzman|     58|Dominican Republic|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|              MANO-D|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|       13|      Unknown|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|      NULL|    1|   NULL|    NULL|   0.0|    NULL|    NULL|       0|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|      0|       0|       0|      0|   NULL|
# |197000000002| 1970|     0|   0|      NULL|       0|      NULL|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          1|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          6|Hostage Taking (K...|       NULL|           NULL|       NULL|           NULL|        7|Government (Diplo...|          45|Diplomatic Person...|Belgian Ambassado...|Nadine Chaval, da...|     21|           Belgium|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|23rd of September...|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|     7|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|       13|      Unknown|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|      NULL|    0|   NULL|    NULL|   0.0|    NULL|    NULL|       0|      NULL|          NULL|     NULL|       NULL|        1|       1|         0|  NULL| NULL|  NULL|       Mexico|     1| 800000.0|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|      0|       1|       1|      1|   NULL|
# |197001000001| 1970|     1|   0|      NULL|       0|      NULL|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          4|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          1|       Assassination|       NULL|           NULL|       NULL|           NULL|       10| Journalists & Media|          54|Radio Journalist/...|    Voice of America|            Employee|    217|     United States|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|             Unknown|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|       13|      Unknown|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|      NULL|    1|   NULL|    NULL|   0.0|    NULL|    NULL|       0|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|     -9|      -9|       1|      1|   NULL|
# |197001000002| 1970|     1|   0|      NULL|       0|      NULL|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          1|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          3|   Bombing/Explosion|       NULL|           NULL|       NULL|           NULL|        7|Government (Diplo...|          46|   Embassy/Consulate|                NULL|        U.S. Embassy|    217|     United States|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|             Unknown|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|        6|   Explosives|          16|Unknown Explosive...|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL| Explosive| NULL|   NULL|    NULL|  NULL|    NULL|    NULL|       1|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|     -9|      -9|       1|      1|   NULL|
# |197001000003| 1970|     1|   0|      NULL|       0|      NULL|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          1|       0|    NULL|   NULL|    1|    1|    1|       -9|       NULL|           NULL|       0|      1|      0|          7|Facility/Infrastr...|       NULL|           NULL|       NULL|           NULL|        7|Government (Diplo...|          46|   Embassy/Consulate|                NULL|      U.S. Consulate|    217|     United States|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|             Unknown|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|        8|   Incendiary|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|Incendiary| NULL|   NULL|    NULL|  NULL|    NULL|    NULL|       1|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|     -9|      -9|       1|      1|   NULL|
# +------------+-----+------+----+----------+--------+----------+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------+--------+-------+-----+-----+-----+---------+-----------+---------------+--------+-------+-------+-----------+--------------------+-----------+---------------+-----------+---------------+---------+--------------------+------------+--------------------+--------------------+--------------------+-------+------------------+---------+-------------+------------+----------------+-----+-------+-------+-----------+---------+-------------+------------+----------------+-----+-------+-------+-----------+--------------------+--------+------+---------+------+---------+------+-----------+-----------+-----------+----------+------+--------+-------+---------+-------------+------+----------+--------------+------+----------+--------------+---------+---------+-------------+------------+--------------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+----------+-----+-------+--------+------+--------+--------+--------+----------+--------------+---------+-----------+---------+--------+----------+------+-----+------+-------------+------+---------+-----------+----------+------------+----------+--------------+------------------+---------+--------+------+------+------+--------+-------+--------+--------+-------+-------+
# only showing top 5 rows
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: long (nullable = true)
#  |-- imonth: long (nullable = true)
#  |-- iday: long (nullable = true)
#  |-- approxdate: string (nullable = true)
#  |-- extended: long (nullable = true)
#  |-- resolution: date (nullable = true)
#  |-- country: long (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: long (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- specificity: long (nullable = true)
#  |-- vicinity: long (nullable = true)
#  |-- location: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- crit1: long (nullable = true)
#  |-- crit2: long (nullable = true)
#  |-- crit3: long (nullable = true)
#  |-- doubtterr: long (nullable = true)
#  |-- alternative: long (nullable = true)
#  |-- alternative_txt: string (nullable = true)
#  |-- multiple: long (nullable = true)
#  |-- success: long (nullable = true)
#  |-- suicide: long (nullable = true)
#  |-- attacktype1: long (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- attacktype2: long (nullable = true)
#  |-- attacktype2_txt: string (nullable = true)
#  |-- attacktype3: long (nullable = true)
#  |-- attacktype3_txt: string (nullable = true)
#  |-- targtype1: long (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- targsubtype1: long (nullable = true)
#  |-- targsubtype1_txt: string (nullable = true)
#  |-- corp1: string (nullable = true)
#  |-- target1: string (nullable = true)
#  |-- natlty1: long (nullable = true)
#  |-- natlty1_txt: string (nullable = true)
#  |-- targtype2: long (nullable = true)
#  |-- targtype2_txt: string (nullable = true)
#  |-- targsubtype2: long (nullable = true)
#  |-- targsubtype2_txt: string (nullable = true)
#  |-- corp2: string (nullable = true)
#  |-- target2: string (nullable = true)
#  |-- natlty2: long (nullable = true)
#  |-- natlty2_txt: string (nullable = true)
#  |-- targtype3: long (nullable = true)
#  |-- targtype3_txt: string (nullable = true)
#  |-- targsubtype3: long (nullable = true)
#  |-- targsubtype3_txt: string (nullable = true)
#  |-- corp3: string (nullable = true)
#  |-- target3: string (nullable = true)
#  |-- natlty3: long (nullable = true)
#  |-- natlty3_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- gsubname: string (nullable = true)
#  |-- gname2: string (nullable = true)
#  |-- gsubname2: string (nullable = true)
#  |-- gname3: string (nullable = true)
#  |-- gsubname3: string (nullable = true)
#  |-- motive: string (nullable = true)
#  |-- guncertain1: long (nullable = true)
#  |-- guncertain2: long (nullable = true)
#  |-- guncertain3: long (nullable = true)
#  |-- individual: long (nullable = true)
#  |-- nperps: long (nullable = true)
#  |-- nperpcap: double (nullable = true)
#  |-- claimed: long (nullable = true)
#  |-- claimmode: long (nullable = true)
#  |-- claimmode_txt: string (nullable = true)
#  |-- claim2: long (nullable = true)
#  |-- claimmode2: long (nullable = true)
#  |-- claimmode2_txt: string (nullable = true)
#  |-- claim3: long (nullable = true)
#  |-- claimmode3: long (nullable = true)
#  |-- claimmode3_txt: string (nullable = true)
#  |-- compclaim: long (nullable = true)
#  |-- weaptype1: long (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- weapsubtype1: long (nullable = true)
#  |-- weapsubtype1_txt: string (nullable = true)
#  |-- weaptype2: long (nullable = true)
#  |-- weaptype2_txt: string (nullable = true)
#  |-- weapsubtype2: long (nullable = true)
#  |-- weapsubtype2_txt: string (nullable = true)
#  |-- weaptype3: long (nullable = true)
#  |-- weaptype3_txt: string (nullable = true)
#  |-- weapsubtype3: long (nullable = true)
#  |-- weapsubtype3_txt: string (nullable = true)
#  |-- weaptype4: long (nullable = true)
#  |-- weaptype4_txt: string (nullable = true)
#  |-- weapsubtype4: long (nullable = true)
#  |-- weapsubtype4_txt: string (nullable = true)
#  |-- weapdetail: string (nullable = true)
#  |-- nkill: long (nullable = true)
#  |-- nkillus: long (nullable = true)
#  |-- nkillter: long (nullable = true)
#  |-- nwound: double (nullable = true)
#  |-- nwoundus: long (nullable = true)
#  |-- nwoundte: long (nullable = true)
#  |-- property: long (nullable = true)
#  |-- propextent: long (nullable = true)
#  |-- propextent_txt: string (nullable = true)
#  |-- propvalue: double (nullable = true)
#  |-- propcomment: string (nullable = true)
#  |-- ishostkid: long (nullable = true)
#  |-- nhostkid: long (nullable = true)
#  |-- nhostkidus: long (nullable = true)
#  |-- nhours: double (nullable = true)
#  |-- ndays: long (nullable = true)
#  |-- divert: string (nullable = true)
#  |-- kidhijcountry: string (nullable = true)
#  |-- ransom: long (nullable = true)
#  |-- ransomamt: double (nullable = true)
#  |-- ransomamtus: double (nullable = true)
#  |-- ransompaid: double (nullable = true)
#  |-- ransompaidus: long (nullable = true)
#  |-- ransomnote: string (nullable = true)
#  |-- hostkidoutcome: long (nullable = true)
#  |-- hostkidoutcome_txt: string (nullable = true)
#  |-- nreleased: long (nullable = true)
#  |-- addnotes: string (nullable = true)
#  |-- scite1: string (nullable = true)
#  |-- scite2: string (nullable = true)
#  |-- scite3: string (nullable = true)
#  |-- dbsource: string (nullable = true)
#  |-- INT_LOG: long (nullable = true)
#  |-- INT_IDEO: long (nullable = true)
#  |-- INT_MISC: long (nullable = true)
#  |-- INT_ANY: long (nullable = true)
#  |-- related: string (nullable = true)

# %%
from pyspark.sql.functions import col, when

df_casted = df_raw

# Convert integer-like columns
int_columns = [
    "iyear", "imonth", "iday",
    "country", "region",
    "attacktype1", "targtype1",
    "success", "suicide",
    "nkill", "nwound"
]

for c in int_columns:
    if c in df_casted.columns:
        df_casted = df_casted.withColumn(c, col(c).cast("int"))

# Convert double/float columns
double_columns = ["latitude", "longitude"]

for c in double_columns:
    if c in df_casted.columns:
        df_casted = df_casted.withColumn(c, col(c).cast("double"))

# Replace null casualties with 0
df_casted = (
    df_casted
    .withColumn("nkill", when(col("nkill").isNull(), 0).otherwise(col("nkill")))
    .withColumn("nwound", when(col("nwound").isNull(), 0).otherwise(col("nwound")))
)

# Create total casualties
df_casted = df_casted.withColumn("casualties", col("nkill") + col("nwound"))

# Convert text fields to string (safety)
string_columns = [
    "country_txt", "region_txt", "provstate", "city",
    "attacktype1_txt", "weaptype1_txt",
    "targtype1_txt", "gname"
]

for c in string_columns:
    if c in df_casted.columns:
        df_casted = df_casted.withColumn(c, col(c).cast("string"))

# Clean invalid coordinates (optional but recommended)
df_casted = df_casted.filter(
    (col("latitude").between(-90, 90)) &
    (col("longitude").between(-180, 180))
)

# Final check
df_casted.printSchema()
df_casted.show(5)
# Out:
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: integer (nullable = true)
#  |-- imonth: integer (nullable = true)
#  |-- iday: integer (nullable = true)
#  |-- approxdate: string (nullable = true)
#  |-- extended: long (nullable = true)
#  |-- resolution: date (nullable = true)
#  |-- country: integer (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: integer (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- specificity: long (nullable = true)
#  |-- vicinity: long (nullable = true)
#  |-- location: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- crit1: long (nullable = true)
#  |-- crit2: long (nullable = true)
#  |-- crit3: long (nullable = true)
#  |-- doubtterr: long (nullable = true)
#  |-- alternative: long (nullable = true)
#  |-- alternative_txt: string (nullable = true)
#  |-- multiple: long (nullable = true)
#  |-- success: integer (nullable = true)
#  |-- suicide: integer (nullable = true)
#  |-- attacktype1: integer (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- attacktype2: long (nullable = true)
#  |-- attacktype2_txt: string (nullable = true)
#  |-- attacktype3: long (nullable = true)
#  |-- attacktype3_txt: string (nullable = true)
#  |-- targtype1: integer (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- targsubtype1: long (nullable = true)
#  |-- targsubtype1_txt: string (nullable = true)
#  |-- corp1: string (nullable = true)
#  |-- target1: string (nullable = true)
#  |-- natlty1: long (nullable = true)
#  |-- natlty1_txt: string (nullable = true)
#  |-- targtype2: long (nullable = true)
#  |-- targtype2_txt: string (nullable = true)
#  |-- targsubtype2: long (nullable = true)
#  |-- targsubtype2_txt: string (nullable = true)
#  |-- corp2: string (nullable = true)
#  |-- target2: string (nullable = true)
#  |-- natlty2: long (nullable = true)
#  |-- natlty2_txt: string (nullable = true)
#  |-- targtype3: long (nullable = true)
#  |-- targtype3_txt: string (nullable = true)
#  |-- targsubtype3: long (nullable = true)
#  |-- targsubtype3_txt: string (nullable = true)
#  |-- corp3: string (nullable = true)
#  |-- target3: string (nullable = true)
#  |-- natlty3: long (nullable = true)
#  |-- natlty3_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- gsubname: string (nullable = true)
#  |-- gname2: string (nullable = true)
#  |-- gsubname2: string (nullable = true)
#  |-- gname3: string (nullable = true)
#  |-- gsubname3: string (nullable = true)
#  |-- motive: string (nullable = true)
#  |-- guncertain1: long (nullable = true)
#  |-- guncertain2: long (nullable = true)
#  |-- guncertain3: long (nullable = true)
#  |-- individual: long (nullable = true)
#  |-- nperps: long (nullable = true)
#  |-- nperpcap: double (nullable = true)
#  |-- claimed: long (nullable = true)
#  |-- claimmode: long (nullable = true)
#  |-- claimmode_txt: string (nullable = true)
#  |-- claim2: long (nullable = true)
#  |-- claimmode2: long (nullable = true)
#  |-- claimmode2_txt: string (nullable = true)
#  |-- claim3: long (nullable = true)
#  |-- claimmode3: long (nullable = true)
#  |-- claimmode3_txt: string (nullable = true)
#  |-- compclaim: long (nullable = true)
#  |-- weaptype1: long (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- weapsubtype1: long (nullable = true)
#  |-- weapsubtype1_txt: string (nullable = true)
#  |-- weaptype2: long (nullable = true)
#  |-- weaptype2_txt: string (nullable = true)
#  |-- weapsubtype2: long (nullable = true)
#  |-- weapsubtype2_txt: string (nullable = true)
#  |-- weaptype3: long (nullable = true)
#  |-- weaptype3_txt: string (nullable = true)
#  |-- weapsubtype3: long (nullable = true)
#  |-- weapsubtype3_txt: string (nullable = true)
#  |-- weaptype4: long (nullable = true)
#  |-- weaptype4_txt: string (nullable = true)
#  |-- weapsubtype4: long (nullable = true)
#  |-- weapsubtype4_txt: string (nullable = true)
#  |-- weapdetail: string (nullable = true)
#  |-- nkill: integer (nullable = true)
#  |-- nkillus: long (nullable = true)
#  |-- nkillter: long (nullable = true)
#  |-- nwound: integer (nullable = true)
#  |-- nwoundus: long (nullable = true)
#  |-- nwoundte: long (nullable = true)
#  |-- property: long (nullable = true)
#  |-- propextent: long (nullable = true)
#  |-- propextent_txt: string (nullable = true)
#  |-- propvalue: double (nullable = true)
#  |-- propcomment: string (nullable = true)
#  |-- ishostkid: long (nullable = true)
#  |-- nhostkid: long (nullable = true)
#  |-- nhostkidus: long (nullable = true)
#  |-- nhours: double (nullable = true)
#  |-- ndays: long (nullable = true)
#  |-- divert: string (nullable = true)
#  |-- kidhijcountry: string (nullable = true)
#  |-- ransom: long (nullable = true)
#  |-- ransomamt: double (nullable = true)
#  |-- ransomamtus: double (nullable = true)
#  |-- ransompaid: double (nullable = true)
#  |-- ransompaidus: long (nullable = true)
#  |-- ransomnote: string (nullable = true)
#  |-- hostkidoutcome: long (nullable = true)
#  |-- hostkidoutcome_txt: string (nullable = true)
#  |-- nreleased: long (nullable = true)
#  |-- addnotes: string (nullable = true)
#  |-- scite1: string (nullable = true)
#  |-- scite2: string (nullable = true)
#  |-- scite3: string (nullable = true)
#  |-- dbsource: string (nullable = true)
#  |-- INT_LOG: long (nullable = true)
#  |-- INT_IDEO: long (nullable = true)
#  |-- INT_MISC: long (nullable = true)
#  |-- INT_ANY: long (nullable = true)
#  |-- related: string (nullable = true)
#  |-- casualties: integer (nullable = true)
#
# +------------+-----+------+----+----------+--------+----------+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------+--------+-------+-----+-----+-----+---------+-----------+---------------+--------+-------+-------+-----------+--------------------+-----------+---------------+-----------+---------------+---------+--------------------+------------+--------------------+--------------------+--------------------+-------+------------------+---------+-------------+------------+----------------+-----+-------+-------+-----------+---------+-------------+------------+----------------+-----+-------+-------+-----------+--------------------+--------+------+---------+------+---------+------+-----------+-----------+-----------+----------+------+--------+-------+---------+-------------+------+----------+--------------+------+----------+--------------+---------+---------+-------------+------------+--------------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+----------+-----+-------+--------+------+--------+--------+--------+----------+--------------+---------+-----------+---------+--------+----------+------+-----+------+-------------+------+---------+-----------+----------+------------+----------+--------------+------------------+---------+--------+------+------+------+--------+-------+--------+--------+-------+-------+----------+
# |     eventid|iyear|imonth|iday|approxdate|extended|resolution|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|specificity|vicinity|location|summary|crit1|crit2|crit3|doubtterr|alternative|alternative_txt|multiple|success|suicide|attacktype1|     attacktype1_txt|attacktype2|attacktype2_txt|attacktype3|attacktype3_txt|targtype1|       targtype1_txt|targsubtype1|    targsubtype1_txt|               corp1|             target1|natlty1|       natlty1_txt|targtype2|targtype2_txt|targsubtype2|targsubtype2_txt|corp2|target2|natlty2|natlty2_txt|targtype3|targtype3_txt|targsubtype3|targsubtype3_txt|corp3|target3|natlty3|natlty3_txt|               gname|gsubname|gname2|gsubname2|gname3|gsubname3|motive|guncertain1|guncertain2|guncertain3|individual|nperps|nperpcap|claimed|claimmode|claimmode_txt|claim2|claimmode2|claimmode2_txt|claim3|claimmode3|claimmode3_txt|compclaim|weaptype1|weaptype1_txt|weapsubtype1|    weapsubtype1_txt|weaptype2|weaptype2_txt|weapsubtype2|weapsubtype2_txt|weaptype3|weaptype3_txt|weapsubtype3|weapsubtype3_txt|weaptype4|weaptype4_txt|weapsubtype4|weapsubtype4_txt|weapdetail|nkill|nkillus|nkillter|nwound|nwoundus|nwoundte|property|propextent|propextent_txt|propvalue|propcomment|ishostkid|nhostkid|nhostkidus|nhours|ndays|divert|kidhijcountry|ransom|ransomamt|ransomamtus|ransompaid|ransompaidus|ransomnote|hostkidoutcome|hostkidoutcome_txt|nreleased|addnotes|scite1|scite2|scite3|dbsource|INT_LOG|INT_IDEO|INT_MISC|INT_ANY|related|casualties|
# +------------+-----+------+----+----------+--------+----------+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------+--------+-------+-----+-----+-----+---------+-----------+---------------+--------+-------+-------+-----------+--------------------+-----------+---------------+-----------+---------------+---------+--------------------+------------+--------------------+--------------------+--------------------+-------+------------------+---------+-------------+------------+----------------+-----+-------+-------+-----------+---------+-------------+------------+----------------+-----+-------+-------+-----------+--------------------+--------+------+---------+------+---------+------+-----------+-----------+-----------+----------+------+--------+-------+---------+-------------+------+----------+--------------+------+----------+--------------+---------+---------+-------------+------------+--------------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+----------+-----+-------+--------+------+--------+--------+--------+----------+--------------+---------+-----------+---------+--------+----------+------+-----+------+-------------+------+---------+-----------+----------+------------+----------+--------------+------------------+---------+--------+------+------+------+--------+-------+--------+--------+-------+-------+----------+
# |197000000001| 1970|     7|   2|      NULL|       0|      NULL|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          1|       Assassination|       NULL|           NULL|       NULL|           NULL|       14|Private Citizens ...|          68|      Named Civilian|                NULL|        Julio Guzman|     58|Dominican Republic|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|              MANO-D|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|       13|      Unknown|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|      NULL|    1|   NULL|    NULL|     0|    NULL|    NULL|       0|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|      0|       0|       0|      0|   NULL|         1|
# |197000000002| 1970|     0|   0|      NULL|       0|      NULL|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          1|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          6|Hostage Taking (K...|       NULL|           NULL|       NULL|           NULL|        7|Government (Diplo...|          45|Diplomatic Person...|Belgian Ambassado...|Nadine Chaval, da...|     21|           Belgium|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|23rd of September...|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|     7|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|       13|      Unknown|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|      NULL|    0|   NULL|    NULL|     0|    NULL|    NULL|       0|      NULL|          NULL|     NULL|       NULL|        1|       1|         0|  NULL| NULL|  NULL|       Mexico|     1| 800000.0|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|      0|       1|       1|      1|   NULL|         0|
# |197001000001| 1970|     1|   0|      NULL|       0|      NULL|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          4|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          1|       Assassination|       NULL|           NULL|       NULL|           NULL|       10| Journalists & Media|          54|Radio Journalist/...|    Voice of America|            Employee|    217|     United States|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|             Unknown|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|       13|      Unknown|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|      NULL|    1|   NULL|    NULL|     0|    NULL|    NULL|       0|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|     -9|      -9|       1|      1|   NULL|         1|
# |197001000002| 1970|     1|   0|      NULL|       0|      NULL|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          1|       0|    NULL|   NULL|    1|    1|    1|        0|       NULL|           NULL|       0|      1|      0|          3|   Bombing/Explosion|       NULL|           NULL|       NULL|           NULL|        7|Government (Diplo...|          46|   Embassy/Consulate|                NULL|        U.S. Embassy|    217|     United States|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|             Unknown|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|        6|   Explosives|          16|Unknown Explosive...|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL| Explosive|    0|   NULL|    NULL|     0|    NULL|    NULL|       1|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|     -9|      -9|       1|      1|   NULL|         0|
# |197001000003| 1970|     1|   0|      NULL|       0|      NULL|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          1|       0|    NULL|   NULL|    1|    1|    1|       -9|       NULL|           NULL|       0|      1|      0|          7|Facility/Infrastr...|       NULL|           NULL|       NULL|           NULL|        7|Government (Diplo...|          46|   Embassy/Consulate|                NULL|      U.S. Consulate|    217|     United States|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|     NULL|         NULL|        NULL|            NULL| NULL|   NULL|   NULL|       NULL|             Unknown|    NULL|  NULL|     NULL|  NULL|     NULL|  NULL|          0|       NULL|       NULL|         0|  NULL|    NULL|   NULL|     NULL|         NULL|  NULL|      NULL|          NULL|  NULL|      NULL|          NULL|     NULL|        8|   Incendiary|        NULL|                NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|     NULL|         NULL|        NULL|            NULL|Incendiary|    0|   NULL|    NULL|     0|    NULL|    NULL|       1|      NULL|          NULL|     NULL|       NULL|        0|    NULL|      NULL|  NULL| NULL|  NULL|         NULL|     0|     NULL|       NULL|      NULL|        NULL|      NULL|          NULL|              NULL|     NULL|    NULL|  NULL|  NULL|  NULL|    PGIS|     -9|      -9|       1|      1|   NULL|         0|
# +------------+-----+------+----+----------+--------+----------+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------+--------+-------+-----+-----+-----+---------+-----------+---------------+--------+-------+-------+-----------+--------------------+-----------+---------------+-----------+---------------+---------+--------------------+------------+--------------------+--------------------+--------------------+-------+------------------+---------+-------------+------------+----------------+-----+-------+-------+-----------+---------+-------------+------------+----------------+-----+-------+-------+-----------+--------------------+--------+------+---------+------+---------+------+-----------+-----------+-----------+----------+------+--------+-------+---------+-------------+------+----------+--------------+------+----------+--------------+---------+---------+-------------+------------+--------------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+---------+-------------+------------+----------------+----------+-----+-------+--------+------+--------+--------+--------+----------+--------------+---------+-----------+---------+--------+----------+------+-----+------+-------------+------+---------+-----------+----------+------------+----------+--------------+------------------+---------+--------+------+------+------+--------+-------+--------+--------+-------+-------+----------+
# only showing top 5 rows

# %%
cols_to_keep = [
    "eventid", "iyear", "imonth", "iday",
    "country", "country_txt",
    "region", "region_txt",
    "provstate", "city",
    "latitude", "longitude",
    "attacktype1", "attacktype1_txt",
    "gname",
    "nkill", "nwound",
    "weaptype1_txt",
    "targtype1_txt",
    "success", "suicide"
]

df = df_raw.select(*cols_to_keep)
df.show(5)
df.printSchema()
# Out:
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+
# |     eventid|iyear|imonth|iday|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|attacktype1|     attacktype1_txt|               gname|nkill|nwound|weaptype1_txt|       targtype1_txt|success|suicide|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+
# |197000000001| 1970|     7|   2|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       Assassination|              MANO-D|    1|   0.0|      Unknown|Private Citizens ...|      1|      0|
# |197000000002| 1970|     0|   0|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          6|Hostage Taking (K...|23rd of September...|    0|   0.0|      Unknown|Government (Diplo...|      1|      0|
# |197001000001| 1970|     1|   0|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          1|       Assassination|             Unknown|    1|   0.0|      Unknown| Journalists & Media|      1|      0|
# |197001000002| 1970|     1|   0|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          3|   Bombing/Explosion|             Unknown| NULL|  NULL|   Explosives|Government (Diplo...|      1|      0|
# |197001000003| 1970|     1|   0|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          7|Facility/Infrastr...|             Unknown| NULL|  NULL|   Incendiary|Government (Diplo...|      1|      0|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+
# only showing top 5 rows
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: long (nullable = true)
#  |-- imonth: long (nullable = true)
#  |-- iday: long (nullable = true)
#  |-- country: long (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: long (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- attacktype1: long (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- nkill: long (nullable = true)
#  |-- nwound: double (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- success: long (nullable = true)
#  |-- suicide: long (nullable = true)

# %%
from pyspark.sql.functions import col

df = (
    df
    .withColumn("iyear", col("iyear").cast("int"))
    .withColumn("imonth", col("imonth").cast("int"))
    .withColumn("iday", col("iday").cast("int"))
    .withColumn("latitude", col("latitude").cast("double"))
    .withColumn("longitude", col("longitude").cast("double"))
    .withColumn("nkill", col("nkill").cast("double"))
    .withColumn("nwound", col("nwound").cast("double"))
    .withColumn("success", col("success").cast("int"))
    .withColumn("suicide", col("suicide").cast("int"))
)
df.show(5)
df.printSchema()
# Out:
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+
# |     eventid|iyear|imonth|iday|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|attacktype1|     attacktype1_txt|               gname|nkill|nwound|weaptype1_txt|       targtype1_txt|success|suicide|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+
# |197000000001| 1970|     7|   2|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       Assassination|              MANO-D|  1.0|   0.0|      Unknown|Private Citizens ...|      1|      0|
# |197000000002| 1970|     0|   0|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          6|Hostage Taking (K...|23rd of September...|  0.0|   0.0|      Unknown|Government (Diplo...|      1|      0|
# |197001000001| 1970|     1|   0|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          1|       Assassination|             Unknown|  1.0|   0.0|      Unknown| Journalists & Media|      1|      0|
# |197001000002| 1970|     1|   0|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          3|   Bombing/Explosion|             Unknown| NULL|  NULL|   Explosives|Government (Diplo...|      1|      0|
# |197001000003| 1970|     1|   0|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          7|Facility/Infrastr...|             Unknown| NULL|  NULL|   Incendiary|Government (Diplo...|      1|      0|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+
# only showing top 5 rows
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: integer (nullable = true)
#  |-- imonth: integer (nullable = true)
#  |-- iday: integer (nullable = true)
#  |-- country: long (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: long (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- attacktype1: long (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- nkill: double (nullable = true)
#  |-- nwound: double (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- success: integer (nullable = true)
#  |-- suicide: integer (nullable = true)

# %%
# incident_date from (iyear, imonth, iday)

# casualties = nkill + nwound

# decade (1970s, 1980s, etc.)

# high_casualty flag (casualties ≥ 10)

from pyspark.sql.functions import when, concat_ws, to_date, lit

# Build a date string "iyear-imonth-iday", but handle 0 month/day as null
df = df.withColumn(
    "date_str",
    when((col("imonth") > 0) & (col("iday") > 0),
         concat_ws("-", col("iyear"), col("imonth"), col("iday")))
    .otherwise(None)
)

df = df.withColumn("incident_date", to_date(col("date_str"), "yyyy-M-d")).drop("date_str")

# Casualties: kills + wounds
df = df.withColumn("nkill", when(col("nkill").isNull(), 0).otherwise(col("nkill")))
df = df.withColumn("nwound", when(col("nwound").isNull(), 0).otherwise(col("nwound")))

df = df.withColumn("casualties", col("nkill") + col("nwound"))

# Decade
df = df.withColumn(
    "decade",
    when(col("iyear") < 1980, "1970s")
    .when(col("iyear") < 1990, "1980s")
    .when(col("iyear") < 2000, "1990s")
    .when(col("iyear") < 2010, "2000s")
    .when(col("iyear") < 2020, "2010s")
    .otherwise("2020s+")
)

# High casualty flag
df = df.withColumn(
    "high_casualty",
    when(col("casualties") >= 10, "High (>=10)")
    .otherwise("Low/Medium (<10)")
)

df.show(5)
df.printSchema()
# Out:
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# |     eventid|iyear|imonth|iday|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|attacktype1|     attacktype1_txt|               gname|nkill|nwound|weaptype1_txt|       targtype1_txt|success|suicide|incident_date|casualties|decade|   high_casualty|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# |197000000001| 1970|     7|   2|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       Assassination|              MANO-D|  1.0|   0.0|      Unknown|Private Citizens ...|      1|      0|   1970-07-02|       1.0| 1970s|Low/Medium (<10)|
# |197000000002| 1970|     0|   0|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          6|Hostage Taking (K...|23rd of September...|  0.0|   0.0|      Unknown|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# |197001000001| 1970|     1|   0|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          1|       Assassination|             Unknown|  1.0|   0.0|      Unknown| Journalists & Media|      1|      0|         NULL|       1.0| 1970s|Low/Medium (<10)|
# |197001000002| 1970|     1|   0|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          3|   Bombing/Explosion|             Unknown|  0.0|   0.0|   Explosives|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# |197001000003| 1970|     1|   0|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          7|Facility/Infrastr...|             Unknown|  0.0|   0.0|   Incendiary|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# only showing top 5 rows
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: integer (nullable = true)
#  |-- imonth: integer (nullable = true)
#  |-- iday: integer (nullable = true)
#  |-- country: long (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: long (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- attacktype1: long (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- nkill: double (nullable = true)
#  |-- nwound: double (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- success: integer (nullable = true)
#  |-- suicide: integer (nullable = true)
#  |-- incident_date: date (nullable = true)
#  |-- casualties: double (nullable = true)
#  |-- decade: string (nullable = false)
#  |-- high_casualty: string (nullable = false)

# %%
# Drop records without year or region
df_clean = df.filter(col("iyear").isNotNull() & col("region_txt").isNotNull())

df_clean.show(5)
df_clean.printSchema()
# Out:
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# |     eventid|iyear|imonth|iday|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|attacktype1|     attacktype1_txt|               gname|nkill|nwound|weaptype1_txt|       targtype1_txt|success|suicide|incident_date|casualties|decade|   high_casualty|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# |197000000001| 1970|     7|   2|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       Assassination|              MANO-D|  1.0|   0.0|      Unknown|Private Citizens ...|      1|      0|   1970-07-02|       1.0| 1970s|Low/Medium (<10)|
# |197000000002| 1970|     0|   0|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          6|Hostage Taking (K...|23rd of September...|  0.0|   0.0|      Unknown|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# |197001000001| 1970|     1|   0|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          1|       Assassination|             Unknown|  1.0|   0.0|      Unknown| Journalists & Media|      1|      0|         NULL|       1.0| 1970s|Low/Medium (<10)|
# |197001000002| 1970|     1|   0|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          3|   Bombing/Explosion|             Unknown|  0.0|   0.0|   Explosives|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# |197001000003| 1970|     1|   0|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          7|Facility/Infrastr...|             Unknown|  0.0|   0.0|   Incendiary|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# only showing top 5 rows
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: integer (nullable = true)
#  |-- imonth: integer (nullable = true)
#  |-- iday: integer (nullable = true)
#  |-- country: long (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: long (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- attacktype1: long (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- nkill: double (nullable = true)
#  |-- nwound: double (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- success: integer (nullable = true)
#  |-- suicide: integer (nullable = true)
#  |-- incident_date: date (nullable = true)
#  |-- casualties: double (nullable = true)
#  |-- decade: string (nullable = false)
#  |-- high_casualty: string (nullable = false)

# %%
df_clean.write.mode("overwrite").saveAsTable("bigdata_finals.default.clean_terror")
