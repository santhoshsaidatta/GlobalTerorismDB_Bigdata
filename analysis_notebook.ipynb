# %%
df = spark.table("bigdata_finals.default.clean_terror")
df.show(5)
df.printSchema()
# Out:
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# |     eventid|iyear|imonth|iday|country|       country_txt|region|          region_txt|provstate|         city| latitude| longitude|attacktype1|     attacktype1_txt|               gname|nkill|nwound|weaptype1_txt|       targtype1_txt|success|suicide|incident_date|casualties|decade|   high_casualty|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# |197000000001| 1970|     7|   2|     58|Dominican Republic|     2|Central America &...|     NULL|Santo Domingo|18.456792|-69.951164|          1|       Assassination|              MANO-D|  1.0|   0.0|      Unknown|Private Citizens ...|      1|      0|   1970-07-02|       1.0| 1970s|Low/Medium (<10)|
# |197000000002| 1970|     0|   0|    130|            Mexico|     1|       North America|  Federal|  Mexico city|19.371887|-99.086624|          6|Hostage Taking (K...|23rd of September...|  0.0|   0.0|      Unknown|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# |197001000001| 1970|     1|   0|    160|       Philippines|     5|      Southeast Asia|   Tarlac|      Unknown|15.478598|120.599741|          1|       Assassination|             Unknown|  1.0|   0.0|      Unknown| Journalists & Media|      1|      0|         NULL|       1.0| 1970s|Low/Medium (<10)|
# |197001000002| 1970|     1|   0|     78|            Greece|     8|      Western Europe|   Attica|       Athens| 37.99749| 23.762728|          3|   Bombing/Explosion|             Unknown|  0.0|   0.0|   Explosives|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# |197001000003| 1970|     1|   0|    101|             Japan|     4|           East Asia|  Fukouka|      Fukouka|33.580412|130.396361|          7|Facility/Infrastr...|             Unknown|  0.0|   0.0|   Incendiary|Government (Diplo...|      1|      0|         NULL|       0.0| 1970s|Low/Medium (<10)|
# +------------+-----+------+----+-------+------------------+------+--------------------+---------+-------------+---------+----------+-----------+--------------------+--------------------+-----+------+-------------+--------------------+-------+-------+-------------+----------+------+----------------+
# only showing top 5 rows
# root
#  |-- eventid: long (nullable = true)
#  |-- iyear: integer (nullable = true)
#  |-- imonth: integer (nullable = true)
#  |-- iday: integer (nullable = true)
#  |-- country: long (nullable = true)
#  |-- country_txt: string (nullable = true)
#  |-- region: long (nullable = true)
#  |-- region_txt: string (nullable = true)
#  |-- provstate: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- attacktype1: long (nullable = true)
#  |-- attacktype1_txt: string (nullable = true)
#  |-- gname: string (nullable = true)
#  |-- nkill: double (nullable = true)
#  |-- nwound: double (nullable = true)
#  |-- weaptype1_txt: string (nullable = true)
#  |-- targtype1_txt: string (nullable = true)
#  |-- success: integer (nullable = true)
#  |-- suicide: integer (nullable = true)
#  |-- incident_date: date (nullable = true)
#  |-- casualties: double (nullable = true)
#  |-- decade: string (nullable = true)
#  |-- high_casualty: string (nullable = true)

# %%
# Basic Stats
df.describe(["nkill", "nwound", "casualties"]).show()
# Out:
# +-------+------------------+------------------+-----------------+
# |summary|             nkill|            nwound|       casualties|
# +-------+------------------+------------------+-----------------+
# |  count|            181691|            181691|           181691|
# |   mean|2.2668596683380025|2.8832963658078827|5.150156034145885|
# | stddev| 11.22705708247857|34.309747287962395|40.55541615668081|
# |    min|               0.0|               0.0|              0.0|
# |    max|            1570.0|            8191.0|           9574.0|
# +-------+------------------+------------------+-----------------+

# %%
# Attack per Year
from pyspark.sql.functions import count

df_attacks_year = (
    df.groupBy("iyear")
      .agg(count("*").alias("num_attacks"))
      .orderBy("iyear")
)
df_attacks_year.show()
# Out:
# +-----+-----------+
# |iyear|num_attacks|
# +-----+-----------+
# | 1970|        651|
# | 1971|        471|
# | 1972|        568|
# | 1973|        473|
# | 1974|        581|
# | 1975|        740|
# | 1976|        923|
# | 1977|       1319|
# | 1978|       1526|
# | 1979|       2662|
# | 1980|       2662|
# | 1981|       2586|
# | 1982|       2544|
# | 1983|       2870|
# | 1984|       3495|
# | 1985|       2915|
# | 1986|       2860|
# | 1987|       3183|
# | 1988|       3721|
# | 1989|       4324|
# +-----+-----------+
# only showing top 20 rows

# %%
# Casualities by Region
from pyspark.sql.functions import sum as spark_sum

df_casualties_region = (
    df.groupBy("region_txt")
      .agg(
          spark_sum("casualties").alias("total_casualties"),
          spark_sum("nkill").alias("total_killed"),
          spark_sum("nwound").alias("total_wounded")
      )
      .orderBy("total_casualties", ascending=False)
)
df_casualties_region.show()
# Out:
# +--------------------+----------------+------------+-------------+
# |          region_txt|total_casualties|total_killed|total_wounded|
# +--------------------+----------------+------------+-------------+
# |Middle East & Nor...|        351950.0|    137642.0|     214308.0|
# |          South Asia|        242679.0|    101319.0|     141360.0|
# |  Sub-Saharan Africa|        131243.0|     78386.0|      52857.0|
# |       South America|         45553.0|     28849.0|      16704.0|
# |      Southeast Asia|         41896.0|     15637.0|      26259.0|
# |Central America &...|         37699.0|     28708.0|       8991.0|
# |       North America|         26447.0|      4916.0|      21531.0|
# |      Western Europe|         25026.0|      6694.0|      18332.0|
# |      Eastern Europe|         19460.0|      7415.0|      12045.0|
# |           East Asia|         10365.0|      1152.0|       9213.0|
# |        Central Asia|          3009.0|      1000.0|       2009.0|
# |Australasia & Oce...|           410.0|       150.0|        260.0|
# +--------------------+----------------+------------+-------------+

# %%
# Top 10 countries by casualities
from pyspark.sql.functions import col
df_top_countries = (
    df.groupBy("country_txt")
      .agg(spark_sum("casualties").alias("total_casualties"))
      .orderBy(col("total_casualties").desc())
      .limit(10)
)
df_top_countries.show()
# Out:
# +-------------+----------------+
# |  country_txt|total_casualties|
# +-------------+----------------+
# |         Iraq|        213279.0|
# |  Afghanistan|         83661.0|
# |     Pakistan|         65860.0|
# |        India|         48321.0|
# |      Nigeria|         32921.0|
# |    Sri Lanka|         31091.0|
# |        Syria|         29338.0|
# |     Colombia|         25026.0|
# |United States|         24473.0|
# |  Philippines|         22926.0|
# +-------------+----------------+

# %%
# Attack type VS Suicide
from pyspark.sql.functions import avg

df_suicide_attacktype = (
    df.groupBy("attacktype1_txt")
      .agg(
          avg("suicide").alias("suicide_rate"),
          avg("casualties").alias("avg_casualties")
      )
      .orderBy(col("suicide_rate").desc())
)
df_suicide_attacktype.show()
# Out:
# +--------------------+--------------------+------------------+
# |     attacktype1_txt|        suicide_rate|    avg_casualties|
# +--------------------+--------------------+------------------+
# |   Bombing/Explosion|  0.0704096085207637| 6.005404792929579|
# |Hostage Taking (B...|0.054490413723511606| 8.520686175580222|
# |           Hijacking| 0.01669195751138088|31.440060698027313|
# |       Assassination|0.013566694283347142| 2.009475973487987|
# |Hostage Taking (K...|0.003405628248790...| 2.749327836529844|
# |     Unarmed Assault|0.001970443349753...|14.686699507389163|
# |       Armed Assault|0.001148374698258689| 5.569921957392955|
# |             Unknown|2.748763056624519E-4|  6.47416162726773|
# |Facility/Infrastr...|9.656237929702588E-5|0.7152375434530707|
# +--------------------+--------------------+------------------+

# %%
# %sql
SELECT
  iyear,
  region_txt,
  COUNT(*) AS num_attacks
FROM bigdata_finals.default.clean_terror
GROUP BY iyear, region_txt
ORDER BY iyear, num_attacks DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
a</td><td>7</td></tr><tr><td>1974</td><td>East Asia</td><td>4</td></tr><tr><td>1974</td><td>Southeast Asia</td><td>3</td></tr><tr><td>1974</td><td>South Asia</td><td>2</td></tr><tr><td>1974</td><td>Eastern Europe</td><td>2</td></tr><tr><td>1974</td><td>Australasia & Oceania</td><td>1</td></tr><tr><td>1975</td><td>Western Europe</td><td>438</td></tr><tr><td>1975</td><td>North America</td><td>159</td></tr><tr><td>1975</td><td>South America</td><td>55</td></tr><tr><td>1975</td><td>Middle East & North Africa</td><td>44</td></tr><tr><td>1975</td><td>East Asia</td><td>12</td></tr><tr><td>1975</td><td>Sub-Saharan Africa</td><td>12</td></tr><tr><td>1975</td><td>Central America & Caribbean</td><td>9</td></tr><tr><td>1975</td><td>Southeast Asia</td><td>7</td></tr><tr><td>1975</td><td>South Asia</td><td>4</td></tr><tr><td>1976</td><td>Western Europe</td><td>578</td></tr><tr><td>1976</td><td>North America</td><td>125</td></tr><tr><td>1976</td><td>South America</td><td>91</td></tr><tr><td>1976</td><td>Middle East & North Af ...

# %%
# %sql
SELECT
  weaptype1_txt,
  SUM(nkill + nwound) AS total_casualties
FROM bigdata_finals.default.clean_terror
GROUP BY weaptype1_txt
ORDER BY total_casualties DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>weaptype1_txt</th><th>total_casualties</th></tr></thead><tbody><tr><td>Explosives</td><td>560181.0</td></tr><tr><td>Firearms</td><td>252113.0</td></tr><tr><td>Unknown</td><td>60195.0</td></tr><tr><td>Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)</td><td>20305.0</td></tr><tr><td>Melee</td><td>16070.0</td></tr><tr><td>Chemical</td><td>14449.0</td></tr><tr><td>Incendiary</td><td>11006.0</td></tr><tr><td>Biological</td><td>814.0</td></tr><tr><td>Sabotage Equipment</td><td>369.0</td></tr><tr><td>Other</td><td>228.0</td></tr><tr><td>Radiological</td><td>6.0</td></tr><tr><td>Fake Weapons</td><td>1.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT
  targtype1_txt,
  SUM(nkill + nwound) AS total_casualties
FROM bigdata_finals.default.clean_terror
GROUP BY targtype1_txt
ORDER BY total_casualties DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>targtype1_txt</th><th>total_casualties</th></tr></thead><tbody><tr><td>Private Citizens & Property</td><td>319176.0</td></tr><tr><td>Military</td><td>177085.0</td></tr><tr><td>Police</td><td>118407.0</td></tr><tr><td>Business</td><td>78018.0</td></tr><tr><td>Government (General)</td><td>67255.0</td></tr><tr><td>Transportation</td><td>54595.0</td></tr><tr><td>Religious Figures/Institutions</td><td>37890.0</td></tr><tr><td>Terrorists/Non-State Militia</td><td>17311.0</td></tr><tr><td>Educational Institution</td><td>13972.0</td></tr><tr><td>Government (Diplomatic)</td><td>13398.0</td></tr><tr><td>Violent Political Party</td><td>8920.0</td></tr><tr><td>Unknown</td><td>7888.0</td></tr><tr><td>Airports & Aircraft</td><td>7245.0</td></tr><tr><td>Journalists & Media</td><td>3297.0</td></tr><tr><td>Utilities</td><td>3227.0</td></tr><tr><td>Maritime</td><td>2099.0</td></tr><tr><td>Tourists</td><td>2048.0</td></tr><tr><td>NGO</td><td>1950.0</td></tr><tr><td>Telecommunication</td><td>679.0</td></tr><tr><td>Other</td><td>674.0</td></tr><tr><td>Food or Water Supply</td><td>547.0</td></tr><tr><td>Abortion Related</td><td>56.0</td></tr></tbody></table></div>
